# %% [markdown]
# # Práctica 1: primera exploración a los datos (winequalityN.cvs)

# %% [markdown]
# ## Alumno: Aguilar Alonso Adriana

# %%
import pandas as pd
import numpy as np
import missingno as msno
# %matplotlib inline

# %%
path = 'winequalityN.csv'
df = pd.read_csv(path)
df.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# 2       0.44     10.1        6
# 3       0.40      9.9        6
# 4       0.40      9.9        6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   object
#  1   fixed acidity         6487 non-null   float64
#  2   volatile acidity      6489 non-null   float64
#  3   citric acid           6494 non-null   float64
#  4   residual sugar        6495 non-null   float64
#  5   chlorides             6495 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6488 non-null   float64
#  10  sulphates             6493 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %%
df.shape
# Out:
# (6497, 13)

# %% [markdown]
# ### Tenemos 119390 datos totales y 32 variables o columnas.

# %%
df.shape[0]
# Out:
# 6497

# %%
df.shape[1]
# Out:
# 13

# %%
df.columns.values.tolist()
# Out:
# ['type',
#  'fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'quality']

# %% [markdown]
# ### Existen valores faltantes.

# %%
df.isnull().any().any()
# Out:
# True

# %%
msno.matrix(df)

# %%
df.replace({' ': np.nan}, inplace=True)

# %%
df.isnull().any().any()
# Out:
# True

# %%
msno.matrix(df)

# %%
msno.bar(df)

# %%
df.columns[df.isnull().any()].tolist()
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'pH',
#  'sulphates']

# %% [markdown]
# ## Número de filas con valores perdidos
#
# ### Resumen de estadísticas

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6487.000000       6489.000000  6494.000000     6495.000000
# mean        7.216579          0.339691     0.318722        5.444326
# std         1.296750          0.164649     0.145265        4.758125
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6495.000000          6497.000000           6497.000000  6497.000000
# mean      0.056042            30.525319            115.744574     0.994697
# std       0.035036            17.749400             56.521855     0.002999
# min       0.009000             1.000000              6.000000     0.987110
# 25%       0.038000            17.000000             77.000000     0.992340
# 50%       0.047000            29.000000            118.000000     0.994890
# 75%       0.065000            41.000000            156.000000     0.996990
# max       0.611000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  6488.000000  6493.000000  6497.000000  6497.000000
# mean      3.218395     0.531215    10.491801     5.818378
# std       0.160748     0.148814     1.192712     0.873255
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.110000     0.430000     9.500000     5.000000
# 50%       3.210000     0.510000    10.300000     6.000000
# 75%       3.320000     0.600000    11.300000     6.000000
# max       4.010000     2.000000    14.900000     9.000000

# %% [markdown]
# ### Seleccionar índice de fila específico

# %%
df.loc[[20]]
# Out:
#      type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 20  white            6.2              0.66         0.48             1.2
#
#     chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 20      0.029                 29.0                  75.0   0.9892  3.33
#
#     sulphates  alcohol  quality
# 20       0.39     12.8        8

# %%
df.type.loc[[20]]
# Out:
# 20    white
# Name: type, dtype: object

# %%
df["fixed acidity"].loc[[0]]
# Out:
# 0    7.0
# Name: fixed acidity, dtype: float64

# %%
df["alcohol"].loc[[5]]
# Out:
# 5    10.1
# Name: alcohol, dtype: float64

# %%
df[["pH", "citric acid"]].loc[[20]]
# Out:
#       pH  citric acid
# 20  3.33         0.48

# %% [markdown]
# ### Seleccionar índices de fila específicos

# %%
df.loc[20:25]
# Out:
#      type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 20  white            6.2              0.66         0.48             1.2
# 21  white            6.4              0.31         0.38             2.9
# 22  white            6.8              0.26         0.42             1.7
# 23  white            7.6              0.67         0.14             1.5
# 24  white            6.6              0.27         0.41             1.3
# 25  white            7.0              0.25         0.32             9.0
#
#     chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 20      0.029                 29.0                  75.0   0.9892  3.33
# 21      0.038                 19.0                 102.0   0.9912  3.17
# 22      0.049                 41.0                 122.0   0.9930  3.47
# 23      0.074                 25.0                 168.0   0.9937  3.05
# 24      0.052                 16.0                 142.0   0.9951  3.42
# 25      0.046                 56.0                 245.0   0.9955  3.25
#
#     sulphates  alcohol  quality
# 20       0.39     12.8        8
# 21       0.35     11.0        7
# 22       0.48     10.5        8
# 23       0.51      9.3        5
# 24       0.47     10.0        6
# 25       0.50     10.4        6

# %% [markdown]
# ### Excluyendo índices de fila específicos

# %%
df.drop([1,4,7], axis=0).head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 5  white            8.1              0.28         0.40             6.9
# 6  white            6.2              0.32         0.16             7.0
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 5      0.050                 30.0                  97.0   0.9951  3.26
# 6      0.045                 30.0                 136.0   0.9949  3.18
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 2       0.44     10.1        6
# 3       0.40      9.9        6
# 5       0.44     10.1        6
# 6       0.47      9.6        6

# %% [markdown]
# ### Excluyendo índices de fila de rango específicos

# %%
df.drop(df.index[2:15], axis=0).head(5)
# Out:
#      type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0   white            7.0              0.27         0.36            20.7
# 1   white            6.3              0.30         0.34             1.6
# 15  white            6.6              0.17         0.38             1.5
# 16  white            6.3              0.48         0.04             1.1
# 17  white            NaN              0.66         0.48             1.2
#
#     chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0       0.045                 45.0                 170.0   1.0010  3.00
# 1       0.049                 14.0                 132.0   0.9940  3.30
# 15      0.032                 28.0                 112.0   0.9914  3.25
# 16      0.046                 30.0                  99.0   0.9928  3.24
# 17      0.029                 29.0                  75.0   0.9892  3.33
#
#     sulphates  alcohol  quality
# 0        0.45      8.8        6
# 1        0.49      9.5        6
# 15       0.55     11.4        7
# 16       0.36      9.6        6
# 17       0.39     12.8        8

# %% [markdown]
# ### Subconjunto basado en desplazamiento desde arriba (abajo)

# %%
df[50:].head()
# Out:
#      type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 50  white            7.2              0.19         0.31             1.6
# 51  white            6.6              0.25         0.29             1.1
# 52  white            6.2              0.16         0.33             1.1
# 53  white            6.4              0.18         0.35             1.0
# 54  white            6.8              0.20         0.59             0.9
#
#     chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 50      0.062                 31.0                 173.0   0.9917  3.35
# 51      0.068                 39.0                 124.0   0.9914  3.34
# 52      0.057                 21.0                  82.0   0.9910  3.32
# 53      0.045                 39.0                 108.0   0.9911  3.31
# 54      0.147                 38.0                 132.0   0.9930   NaN
#
#     sulphates  alcohol  quality
# 50       0.44     11.7        6
# 51       0.58     11.0        7
# 52       0.46     10.9        7
# 53       0.35     10.9        6
# 54       0.38      9.1        6

# %%
df.quality.values
# Out:
# array([6, 6, 6, ..., 6, 5, 6], dtype=int64)

# %%
df[['quality', "citric acid"]].values
# Out:
# array([[6.  , 0.36],
#        [6.  , 0.34],
#        [6.  , 0.4 ],
#        ...,
#        [6.  , 0.13],
#        [5.  , 0.12],
#        [6.  , 0.47]])

# %%
df.sulphates.unique()
# Out:
# array([0.45, 0.49, 0.44, 0.4 , 0.47, 0.56, 0.53, 0.63, 0.52, 0.67, 0.55,
#        0.36, 0.39, 0.5 , 0.35, 0.48, 0.51, 0.71, 0.37, 0.42, 0.28, 0.34,
#        0.46, 0.58, 0.38, 0.54, 0.64, 0.6 , 0.65, 0.77, 0.41, 0.3 , 0.59,
#        0.57, 0.43, 0.32, 0.84, 0.33, 0.29, 0.27, 0.68, 0.66, 0.61, 0.74,
#         nan, 0.79, 0.7 , 0.62, 0.85, 0.76, 0.75, 0.78, 0.69, 0.72, 0.73,
#        0.96, 0.97, 0.82, 0.95, 0.9 , 0.88, 0.31, 0.25, 0.8 , 0.87, 0.86,
#        0.81, 0.92, 0.26, 0.98, 1.06, 1.  , 0.89, 0.94, 0.99, 0.22, 0.23,
#        0.83, 1.01, 1.08, 1.56, 0.93, 1.28, 0.91, 1.2 , 1.12, 1.14, 1.95,
#        1.22, 1.98, 1.31, 2.  , 1.59, 1.02, 1.03, 1.61, 1.09, 1.26, 1.36,
#        1.18, 1.13, 1.04, 1.11, 1.07, 1.05, 1.17, 1.62, 1.34, 1.16, 1.1 ,
#        1.15, 1.33])

# %%
df.pH.unique()
# Out:
# array([3.  , 3.3 , 3.26, 3.19, 3.18, 3.22, 2.99, 3.14, 3.54, 2.98, 3.25,
#        3.24, 3.33, 3.12, 3.17, 3.47, 3.05, 3.42, 3.45, 3.38, 3.1 , 3.2 ,
#        3.37, 3.13, 3.21, 3.11, 3.16, 3.27, 3.36, 3.35, 3.34, 3.32, 3.31,
#         nan, 3.09, 3.03, 3.02, 3.15, 3.69, 2.95, 2.94, 3.39, 3.04, 2.89,
#        3.4 , 3.01, 3.63, 3.29, 3.23, 3.28, 3.06, 3.08, 2.87, 2.93, 3.44,
#        3.5 , 3.48, 3.72, 3.53, 3.52, 2.96, 3.61, 3.43, 3.49, 3.51, 3.46,
#        3.07, 2.97, 3.41, 3.64, 3.56, 2.86, 2.88, 2.85, 3.58, 3.55, 3.66,
#        3.59, 2.74, 2.92, 3.82, 3.81, 3.65, 2.9 , 3.77, 2.91, 3.62, 3.74,
#        2.8 , 3.6 , 2.72, 2.79, 3.57, 3.8 , 3.68, 2.77, 3.79, 3.7 , 2.84,
#        3.76, 2.83, 3.75, 2.82, 3.67, 3.9 , 3.85, 3.71, 3.78, 4.01])

# %%
df.pH.value_counts()
# Out:
# 3.16    200
# 3.14    193
# 3.22    185
# 3.20    176
# 3.19    170
#        ...
# 3.81      1
# 2.77      1
# 2.82      1
# 2.84      1
# 3.82      1
# Name: pH, Length: 108, dtype: int64

# %% [markdown]
# ### Obtenga el número de valores únicos para cada columna

# %%
df.agg(['count', 'size', 'nunique'])
# Out:
#          type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497           6487              6489         6494            6495
# size     6497           6497              6497         6497            6497
# nunique     2            106               187           89             316
#
#          chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# count         6495                 6497                  6497     6497  6488
# size          6497                 6497                  6497     6497  6497
# nunique        214                  135                   276      998   108
#
#          sulphates  alcohol  quality
# count         6493     6497     6497
# size          6497     6497     6497
# nunique        111      111        7

# %% [markdown]
# ### Un agg dentro de un grupo Andstack al final.

# %%
df.groupby('alcohol').agg(['count', 'size', 'nunique']).stack()
# Out:
#                  type  fixed acidity  volatile acidity  citric acid  \
# alcohol
# 8.0     count       2              2                 2            2
#         size        2              2                 2            2
#         nunique     1              2                 2            2
# 8.4     count       5              5                 5            5
#         size        5              5                 5            5
# ...               ...            ...               ...          ...
# 14.2    size        1              1                 1            1
#         nunique     1              1                 1            1
# 14.9    count       1              1                 1            1
#         size        1              1                 1            1
#         nunique     1              1                 1            1
#
#                  residual sugar  chlorides  free sulfur dioxide  \
# alcohol
# 8.0     count                 2          2                    2
#         size                  2          2                    2
#         nunique               2          2                    2
# 8.4     count                 5          5                    5
#         size                  5          5                    5
# ...                         ...        ...                  ...
# 14.2    size                  1          1                    1
#         nunique               1          1                    1
# 14.9    count                 1          1                    1
#         size                  1          1                    1
#         nunique               1          1                    1
#
#                  total sulfur dioxide  density  pH  sulphates  quality
# alcohol
# 8.0     count                       2        2   2          2        2
#         size                        2        2   2          2        2
#         nunique                     2        2   2          2        2
# 8.4     count                       5        5   5          5        5
#         size                        5        5   5          5        5
# ...                               ...      ...  ..        ...      ...
# 14.2    size                        1        1   1          1        1
#         nunique                     1        1   1          1        1
# 14.9    count                       1        1   1          1        1
#         size                        1        1   1          1        1
#         nunique                     1        1   1          1        1
#
# [333 rows x 12 columns]

# %%
df.groupby('alcohol').agg(['count', 'size', 'nunique'])
# Out:
#          type              fixed acidity              volatile acidity       \
#         count size nunique         count size nunique            count size
# alcohol
# 8.00        2    2       1             2    2       2                2    2
# 8.40        5    5       2             5    5       4                5    5
# 8.50       10   10       2            10   10       8               10   10
# 8.60       23   23       1            23   23      11               23   23
# 8.70       80   80       2            80   80      21               79   80
# ...       ...  ...     ...           ...  ...     ...              ...  ...
# 13.90       3    3       1             3    3       2                3    3
# 14.00      12   12       2            12   12       7               12   12
# 14.05       1    1       1             1    1       1                1    1
# 14.20       1    1       1             1    1       1                1    1
# 14.90       1    1       1             1    1       1                1    1
#
#                 citric acid  ... density    pH              sulphates       \
#         nunique       count  ... nunique count size nunique     count size
# alcohol                      ...
# 8.00          2           2  ...       2     2    2       2         2    2
# 8.40          3           5  ...       4     5    5       3         5    5
# 8.50          8          10  ...       9    10   10       9        10   10
# 8.60         11          23  ...      15    23   23      11        23   23
# 8.70         28          80  ...      39    80   80      26        80   80
# ...         ...         ...  ...     ...   ...  ...     ...       ...  ...
# 13.90         3           3  ...       3     3    3       3         3    3
# 14.00         9          12  ...      10    12   12      10        12   12
# 14.05         1           1  ...       1     1    1       1         1    1
# 14.20         1           1  ...       1     1    1       1         1    1
# 14.90         1           1  ...       1     1    1       1         1    1
#
#                 quality
#         nunique   count size nunique
# alcohol
# 8.00          2       2    2       2
# 8.40          4       5    5       4
# 8.50          9      10   10       4
# 8.60         11      23   23       4
# 8.70         23      80   80       4
# ...         ...     ...  ...     ...
# 13.90         2       3    3       1
# 14.00         7      12   12       3
# 14.05         1       1    1       1
# 14.20         1       1    1       1
# 14.90         1       1    1       1
#
# [111 rows x 36 columns]

# %%
df_sample = df.sample(frac=0.05, random_state=4)
df_sample.head()
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 5214    red            9.6              0.56         0.23            3.40
# 13    white            6.6              0.16         0.40            1.50
# 4735  white            6.0              0.17         0.36            1.70
# 3451  white            6.6              0.21         0.29            5.35
# 991   white            8.2              0.26         0.44            1.30
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 5214      0.102                 37.0                  92.0  0.99960  3.30
# 13        0.044                 48.0                 143.0  0.99120  3.54
# 4735      0.042                 14.0                  61.0  0.99144  3.22
# 3451      0.029                 43.0                 106.0  0.99112  2.93
# 991       0.046                  7.0                  69.0  0.99440  3.14
#
#       sulphates  alcohol  quality
# 5214       0.65     10.1        5
# 13         0.52     12.4        7
# 4735       0.54     10.8        6
# 3451       0.43     11.5        7
# 991        0.62     10.2        4

# %%
df.shape
# Out:
# (6497, 13)

# %%
df_sample.shape
# Out:
# (325, 13)

# %% [markdown]
# ## Transformación de datos
# ### Eliminar filas con conteo faltante

# %%
df_dropped = df.dropna(subset=['density'])
df_dropped.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# 2       0.44     10.1        6
# 3       0.40      9.9        6
# 4       0.40      9.9        6

# %%
df_dropped.shape
# Out:
# (6497, 13)

# %% [markdown]
# ### Copia de df

# %%
df_copy = df.copy()
df_copy.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# 2       0.44     10.1        6
# 3       0.40      9.9        6
# 4       0.40      9.9        6

# %%
df_copy.shape
# Out:
# (6497, 13)

# %%
df_dropped['alcohol'].dtype
# Out:
# dtype('float64')

# %%
df_dropped['alcohol'].mean()
# Out:
# 10.491800831149455

# %%
df_copy['alcohol'].fillna(value=np.round(df['alcohol'].mean(),decimals=0), inplace=True)

# %%
df_copy.agg(['count', 'size', 'nunique'])
# Out:
#          type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497           6487              6489         6494            6495
# size     6497           6497              6497         6497            6497
# nunique     2            106               187           89             316
#
#          chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# count         6495                 6497                  6497     6497  6488
# size          6497                 6497                  6497     6497  6497
# nunique        214                  135                   276      998   108
#
#          sulphates  alcohol  quality
# count         6493     6497     6497
# size          6497     6497     6497
# nunique        111      111        7

# %% [markdown]
# ## Manejo de datos categóricos

# %%
list(df['quality'].unique())
# Out:
# [6, 5, 7, 8, 4, 3, 9]

# %%
"""
3 Nivel 3
4 Nivel 4
5 Nivel 5
6 Nivel 6
7 Nivel 7
8 Nivel 8
9 Nivel 9
"""
df['quality'].replace({3:"Nivel 3", 
                       4:"Nivel 4",
                       5:"Nivel 5", 
                       6:"Nivel 6", 
                       7:"Nivel 7",
                        8:"Nivel 8", 
                       9:"Nivel 9"}, inplace=True)

# %%
list(df['quality'].unique())
# Out:
# ['Nivel 6', 'Nivel 5', 'Nivel 7', 'Nivel 8', 'Nivel 4', 'Nivel 3', 'Nivel 9']

# %% [markdown]
# ### Crear un diccionario

# %%
keys = list(df['quality'].unique())
vals = range(1,8)
act = dict(zip(keys, vals))
act
# Out:
# {'Nivel 6': 1,
#  'Nivel 5': 2,
#  'Nivel 7': 3,
#  'Nivel 8': 4,
#  'Nivel 4': 5,
#  'Nivel 3': 6,
#  'Nivel 9': 7}

# %%
df_copy['quality_cat'] = df['quality'].map(act)
df_copy.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality  quality_cat
# 0       0.45      8.8        6            1
# 1       0.49      9.5        6            1
# 2       0.44     10.1        6            1
# 3       0.40      9.9        6            1
# 4       0.40      9.9        6            1

# %%
list(df_copy['quality_cat'].unique())
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %% [markdown]
# ## Resumen de datos

# %% [markdown]
# ### Preparar una representación compacta de datos en bruto a la mano
#
# ### Agregación de datos utilizando diferentes métodos estadísticos, matemáticos y de otro tipo. El resumen es útil para la visualización, la compresión de datos en bruto y una mejor comprensión de sus atributos.

# %%
df_copy['citric acid'].mean()
# Out:
# 0.3187218971358176

# %%
df_copy['citric acid'][df_copy['quality'] == 3]
# Out:
# 251     0.21
# 253     0.44
# 294     0.38
# 445     0.32
# 740     0.40
# 873     0.47
# 1034    0.46
# 1229    0.42
# 1417    0.35
# 1484    0.24
# 1688    0.26
# 1931    0.22
# 2050    0.38
# 2373    0.37
# 3087    0.34
# 3265    0.23
# 3307    0.29
# 3409    0.35
# 3810    0.34
# 4745    0.25
# 5357    0.66
# 5415    0.49
# 5588    0.00
# 5730    0.42
# 5797    0.02
# 6197    0.00
# 6272    0.00
# 6367    0.05
# 6376    0.05
# 6403    0.02
# Name: citric acid, dtype: float64

# %%
df_copy['citric acid'][df_copy['quality'] == 3].mean()
# Out:
# 0.28099999999999997

# %%
df_copy.groupby(["citric acid", "residual sugar", "quality", "density"]).count()
# Out:
#                                             type  fixed acidity  \
# citric acid residual sugar quality density
# 0.00        0.80           4       0.99032     1              1
#                                    0.99320     1              1
#                            5       0.99286     1              1
#             1.20           3       0.99471     1              1
#                            6       0.99258     2              2
# ...                                          ...            ...
# 1.00        19.50          6       0.99770     1              1
#             19.60          6       0.99730     1              1
#             19.95          6       0.99742     1              1
# 1.23        4.60           6       0.99018     1              1
# 1.66        2.10           6       0.99165     1              1
#
#                                             volatile acidity  chlorides  \
# citric acid residual sugar quality density
# 0.00        0.80           4       0.99032                 1          1
#                                    0.99320                 1          1
#                            5       0.99286                 1          1
#             1.20           3       0.99471                 1          1
#                            6       0.99258                 2          2
# ...                                                      ...        ...
# 1.00        19.50          6       0.99770                 1          1
#             19.60          6       0.99730                 1          1
#             19.95          6       0.99742                 1          1
# 1.23        4.60           6       0.99018                 1          1
# 1.66        2.10           6       0.99165                 1          1
#
#                                             free sulfur dioxide  \
# citric acid residual sugar quality density
# 0.00        0.80           4       0.99032                    1
#                                    0.99320                    1
#                            5       0.99286                    1
#             1.20           3       0.99471                    1
#                            6       0.99258                    2
# ...                                                         ...
# 1.00        19.50          6       0.99770                    1
#             19.60          6       0.99730                    1
#             19.95          6       0.99742                    1
# 1.23        4.60           6       0.99018                    1
# 1.66        2.10           6       0.99165                    1
#
#                                             total sulfur dioxide  pH  \
# citric acid residual sugar quality density
# 0.00        0.80           4       0.99032                     1   1
#                                    0.99320                     1   1
#                            5       0.99286                     1   1
#             1.20           3       0.99471                     1   1
#                            6       0.99258                     2   2
# ...                                                          ...  ..
# 1.00        19.50          6       0.99770                     1   1
#             19.60          6       0.99730                     1   1
#             19.95          6       0.99742                     1   1
# 1.23        4.60           6       0.99018                     1   1
# 1.66        2.10           6       0.99165                     1   1
#
#                                             sulphates  alcohol  quality_cat
# citric acid residual sugar quality density
# 0.00        0.80           4       0.99032          1        1            1
#                                    0.99320          1        1            1
#                            5       0.99286          1        1            1
#             1.20           3       0.99471          1        1            1
#                            6       0.99258          2        2            2
# ...                                               ...      ...          ...
# 1.00        19.50          6       0.99770          1        1            1
#             19.60          6       0.99730          1        1            1
#             19.95          6       0.99742          1        1            1
# 1.23        4.60           6       0.99018          1        1            1
# 1.66        2.10           6       0.99165          1        1            1
#
# [5251 rows x 10 columns]

# %%
df_copy.groupby(["citric acid", "residual sugar"])[["quality", "density"]].count()
# Out:
#                             quality  density
# citric acid residual sugar
# 0.00        0.80                  3        3
#             1.20                  4        4
#             1.30                  2        2
#             1.40                 12       12
#             1.50                  2        2
# ...                             ...      ...
# 1.00        19.50                 1        1
#             19.60                 1        1
#             19.95                 1        1
# 1.23        4.60                  1        1
# 1.66        2.10                  1        1
#
# [2984 rows x 2 columns]

# %%
df_sample = df.sample(frac=0.05, random_state=1)
df_sample.head()
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 3772  white            6.3              0.24         0.29            13.7
# 6009    red            5.4              0.42         0.27             2.0
# 3464  white            6.9              0.29         0.41             7.8
# 1518  white            8.4              0.23         0.49             7.8
# 3761  white            6.1              0.17         0.28             2.5
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 3772      0.035                 53.0                 134.0  0.99567  3.17
# 6009      0.092                 23.0                  55.0  0.99471  3.78
# 3464      0.046                 52.0                 171.0  0.99537  3.12
# 1518      0.035                 22.0                  95.0  0.99350  3.04
# 3761      0.028                 22.0                  98.0  0.99072  3.16
#
#       sulphates  alcohol  quality
# 3772       0.38     10.6  Nivel 6
# 6009       0.64     12.3  Nivel 7
# 3464       0.51      9.6  Nivel 5
# 1518       0.34     12.0  Nivel 6
# 3761       0.37     11.1  Nivel 7

# %%
df_sample.groupby(["citric acid", "residual sugar"])[["quality", "density"]].agg([np.sum, np.mean,
                                                              np.count_nonzero])
# Out:
#                             density
#                                 sum     mean count_nonzero
# citric acid residual sugar
# 0.00        1.6             0.99635  0.99635           1.0
#             1.9             0.99675  0.99675           1.0
#             3.0             0.99650  0.99650           1.0
#             5.6             0.99360  0.99360           1.0
# 0.01        2.6             0.99621  0.99621           1.0
# ...                             ...      ...           ...
# 0.74        12.8            0.99420  0.99420           1.0
# 0.76        3.7             1.00320  1.00320           1.0
# 0.78        9.9             0.99435  0.99435           1.0
# 0.91        8.2             0.99394  0.99394           1.0
# 1.00        1.1             0.99310  0.99310           1.0
#
# [300 rows x 3 columns]

# %% [markdown]
# ## Visualización de datos

# %% [markdown]
# ### Subtramas a mano. El método más básico para crear ejes es usar la función plt.axes

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

ax1 = plt.axes()  # standard axes
ax2 = plt.axes([0.65, 0.65, 0.2, 0.2])

# %%
fig = plt.figure()
ax1 = fig.add_axes([0.1, 0.5, 0.8, 0.4],
                   xticklabels=[], ylim=(-1.2, 1.2))
ax2 = fig.add_axes([0.1, 0.1, 0.8, 0.4],
                   ylim=(-1.2, 1.2))

x = np.linspace(0, 10)
ax1.plot(np.sin(x))
ax2.plot(np.cos(x))

# %%
for i in range(1, 7):
    plt.subplot(2, 3, i)
    plt.text(0.5, 0.5, str((2, 3, i)),
             fontsize=18, ha='center')

# %%
fig = plt.figure()
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i in range(1, 7):
    ax = fig.add_subplot(2, 3, i)
    ax.text(0.5, 0.5, str((2, 3, i)),
           fontsize=18, ha='center')

# %%
fig, ax = plt.subplots(2, 3, sharex='col', sharey='row')

# %%
for i in range(2):
    for j in range(3):
        ax[i, j].text(0.5, 0.5, str((i, j)),
                      fontsize=18, ha='center')
fig

# %%
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 3000).T

# Set up the axes with gridspec
fig = plt.figure(figsize=(6, 6))
grid = plt.GridSpec(4, 4, hspace=0.2, wspace=0.2)
main_ax = fig.add_subplot(grid[:-1, 1:])
y_hist = fig.add_subplot(grid[:-1, 0], xticklabels=[], sharey=main_ax)
x_hist = fig.add_subplot(grid[-1, 1:], yticklabels=[], sharex=main_ax)

# scatter points on the main axes
main_ax.plot(x, y, 'ok', markersize=3, alpha=0.2)

# histogram on the attached axes
x_hist.hist(x, 40, histtype='stepfilled',
            orientation='vertical', color='gray')
x_hist.invert_yaxis()

y_hist.hist(y, 40, histtype='stepfilled',
            orientation='horizontal', color='gray')
y_hist.invert_xaxis()

# %% [markdown]
# ## Gráfico de dispersión

# %% [markdown]
# ### Variables capaces de estar altamente correlacionadas. Para confirmar o validar nuestra hipótesis.

# %%
plt.hist(df_sample['quality'])
plt.xlabel('quality')
plt.ylabel('Frequency')
plt.title('Frequency of quality')
# Out:
# Text(0.5, 1.0, 'Frequency of quality')

# %%
plt.hist(df_sample['pH'])
plt.xlabel('pH')
plt.ylabel('Frequency')
plt.title('Frequency of pH')
# Out:
# Text(0.5, 1.0, 'Frequency of pH')

# %% [markdown]
# ## Diagramas de caja
# Los diagramas de caja son otra forma de entender la distribución de una variable numérica. Especifica algo llamado cuartiles.
#
# Si los números en una distribución con 100 números están ordenados en orden creciente;
# * el primer cuartil ocupará la posición 25
# * el tercer cuartil ocupará la posición 75, y así sucesivamente.
# * La mediana será el promedio de los términos 50 y 51.
# * La mediana es el término medio cuando los números en la distribución se ordenan en orden creciente.
# * El modo es el que ocurre con la frecuencia máxima,
# * mientras que la media es la suma de todos los números divididos por su recuento total.

# %%
plt.boxplot(df_sample['pH'], showmeans=True, meanline=True)
plt.ylabel('pH')
plt.title('Box Plot of pH count')
# Out:
# Text(0.5, 1.0, 'Box Plot of pH count')
